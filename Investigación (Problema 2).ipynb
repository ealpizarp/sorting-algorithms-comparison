# %% [markdown]
# # IC 3002 - Análisis de algoritmos
#
# # Proyecto 1
#
#
# # Problema a analizar
#
# * Considerando los algoritmos de ordenamiento por intercambio de adyacentes (selección, inserción, burbuja original, burbuja optimizado), se sabe que presentan complejidad temporal cuadrática en sus casos promedio y peor. A pesar de que su consumo de recurso temporal cae en la misma clase de complejidad, ¿cómo se comparan en cuanto a rendimiento temporal? ¿Hay alguno más eficiente? Si es el caso, ¿cómo se justifica esta diferencia en eficiencia?
#
# ## Propuesta resolutiva
#
# ### Hipotesis propuesta
#
# * En cuanto al rendimiento temporal y en cuanto a saber si un algoritmo es más eficiente que otro, hay diferentes factores que afectan la complejidad y la eficiencia de cada algoritmo, como por ejemplo los recursos que tenga la máquina. Solo haciendo las pruebas se puede determinar cual algoritmo es mas eficiente basandonos en el rendimiento temporal.
#
# ### Procedimiento para demostrar
#
# * Para demostrar esto se realizarán pruebas empiricas en cada uno de los algoritmos. Se analizarán los casos que éstos tengan y se estará haciendo una comparación de los tiempos de ejecución, asimismo, se graficará la curva respectiva del comportamiento.
#
#
# * Al completar los procesos mencionados anteriormente se proseguirá con la comparación de los resultados empíricos con base al rendimiento temporal concluyendo si hay alguno mas eficiente que otro.
#
# ## Esperimentos
#
# ### Experimento 1
#
# El primer experimento se basa en determinar el rendimiento temporal de cada algortimo segun su peor caso. Para esto vamos a hacer una prueba para cada algoritmo, va a consistir en medir el comportamiento del algoritmo en un punto de crecimiento. Se va a realizar con los siguientes parametros:
#
# * Punto de inicio = 500, Punto final = 2000, 50 ejecuciones y 5 repeticiones por cada muestra.
#
# Al ser concluidas las pruebas compararemos los resultados de los tiempos de ejecución de cada algoritmo, despues graficaremos el comportamiento empírico del algoritmo así como la curva del comportamiento teorico con la estimación de tiempo brindada por la biblioteca BIG O.
#
#
# ### Experimento 2
#
# El primer experimento se basa en determinar el rendimiento temporal de cada algortimo segun su caso promedio. Para esto vamos a hacer una prueba para cada algoritmo, va a consistir en medir el comportamiento del algoritmo en un punto de crecimiento. Se va a realizar con los siguientes parametros:
#
# * Punto de inicio = 500, Punto final = 3500, 50 ejecuciones y 5 repeticiones por cada muestra.
#
# Al ser concluidas las pruebas compararemos los resultados de los tiempos de ejecución de cada algoritmo, despues graficaremos el comportamiento empírico del algoritmo así como la curva del comportamiento teorico con la estimación de tiempo brindada por la biblioteca BIG O.
#
# ### Experimento 3
#
# El primer experimento se basa en determinar el rendimiento temporal de cada algortimo segun su mejor caso. Para esto vamos a hacer una prueba para cada algoritmo, va a consistir en medir el comportamiento del algoritmo en un punto de crecimiento. Se va a realizar con los siguientes parametros:
#
# * Punto de inicio = 500, Punto final = 1000, 50 ejecuciones y 5 repeticiones por cada muestra.
#
# Al ser concluidas las pruebas compararemos los resultados de los tiempos de ejecución de cada algoritmo, despues graficaremos el comportamiento empírico del algoritmo así como la curva del comportamiento teorico con la estimación de tiempo brindada por la biblioteca BIG O.
#
#
# ## Representación
#
# Para la graficación de los resultados vamos a utilizar la biblioteca matplotlib.

# %%
from math import log

xs = range(1, 100)
ys_1 = [x ** 2.01 for x in xs]
ys_2 = [x ** 2 for x in xs]

# %%
import matplotlib.pyplot as plt

plt.plot(xs, ys_1, label = 'Resultados empiricos')
plt.plot(xs, ys_2, label = 'Resultados teoricos')
plt.ylabel('Tamaño')
plt.xlabel('Tiempo')
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# El gráfico anterior solo es una representación no significativa de los graficos y comparaciones que vamos a estar haciendo durante este análisis.

# %% [markdown]
# ### Cálculo de tiempos de ejecución
#
# Como se mencionó anteriormente para calcular los tiempos de ejecución vamos a utilizar la biblioteca BIG O, la cual recibe los siguientes parámetros:
#
#   big_o(
#
#   <función a medir>,
#
#   <función de generación de arreglos>,
#
#   min_n=<límite inferior de tamaños de arreglo>,
#
#   max_n=<límite superior de tamaños de arreglo>,
#
#   n_measures=<número de muestras a probar, las muestras siempre
#
#   estarán entre [min_n .. max_n]>,
#
#   n_repeats=<número de veces que se ejecutará la función con cada muestra>,
#
#   verbose=<False para reducir el número de mensajes producidos por la ejecución de esta función>,
#
#   classes=<el algoritmo trata de determinar si los resultados de la medición calzan con la clase asintótica pasada por este parámetro>,
#
#   return_raw_data=<True para obtener los datos de tamaño de arreglo y tiempo de ejecución de la función medida>
#
# )

# %% [markdown]
# ### Algoritmos a utilizar
#
# * A continuación vamos a mostrar cuales son los algoritmos que vamos a utilizar para realizar los experimentos.
#
# ### Slection Sort

# %%
def selectionSort(arreglo):
  n = len(arreglo)
  for i in range(n):
    minimo = i

    for j in range(i+1, n):
      if (arreglo[j] < arreglo[minimo]):
        minimo = j

    temp = arreglo[i]
    arreglo[i] = arreglo[minimo]
    arreglo[minimo] = temp
    
  return arreglo

# %% [markdown]
# ### Insertion Sort

# %%
def insertionSort(arreglo): 
  
    for i in range(len(arreglo)): 
        
        j = i 
        
        while j > 0 and arreglo[j] < arreglo[j - 1]:
                temp = arreglo[j]
                arreglo[j] = arreglo[j - 1]
                arreglo[j-1] = temp
                j -= 1

    return arreglo

# %% [markdown]
# ### Bubble Sort

# %%
def bubbleSort(arreglo):
    n = len(arreglo)
    i = n-1
    while  i > 0:
        for j in range(0, i):
            if arreglo[j] > arreglo[j+1] :
                arreglo[j], arreglo[j+1] = arreglo[j+1], arreglo[j]
        i -= 1
    return arreglo

# %% [markdown]
# ### Bubble Sort Optimized

# %%
def optimizedBubbleSort(arreglo):
    update=True
    n=len(arreglo)
    while(update==True and n>1):
        update = False
        for i in range(len(arreglo)-1):
            if arreglo[i]>arreglo[i+1]:
                arreglo[i],arreglo[i+1]=arreglo[i+1],arreglo[i]
                update = True
        n-=1
    return arreglo

# %% [markdown]
# Antes de empezar con la reproducción de experimentos vamos a importar algunas funciones necesarias para ejecutar las pruebas y los algoritmos que vamos a usar

# %%
import required_functions as gen

from required_functions import *

import sorting_algorithms as alg

from math import log

import matplotlib.pyplot as plt

# %% [markdown]
# ## Reproducción experimento 1
# Como se ha mencionado anteriormente, haremos la reproducción del experimento para el peor caso con una muestra de minima en 500 y maxima en 2000
#
# ### Selection Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_sel_exp_1 = big_o(alg.selectionSort, 
                     gen.generar_ordenado_des,
                     min_n=500, max_n=2000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_sel_exp_1)
# Out:
# Quadratic: time = 0.00065 + 1.1E-07*n^2 (sec)  (r=0.0007367822157613158, r^2=0.9990738289991306)

# %% [markdown]
# ### Insertion Sort
#
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_ins_exp_1 = big_o(alg.insertionSort, 
                     gen.generar_ordenado_des,
                     min_n=500, max_n=2000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_ins_exp_1)
# Out:
# Quadratic: time = -0.0027 + 7.8E-08*n^2 (sec)  (r=0.0003851211025943286, r^2=0.9989858208631108)

# %% [markdown]
# ### Bubble Sort
#
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_exp_1 = big_o(alg.bubbleSort, 
                     gen.generar_ordenado_des,
                     min_n=500, max_n=2000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_bub_exp_1)
# Out:
# Quadratic: time = -0.0081 + 1.8E-07*n^2 (sec)  (r=0.0023908238917959763, r^2=0.9988595193217236)

# %% [markdown]
# ### Optimized  Bubble Sort
#
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_opt_exp_1 = big_o(alg.optimizedBubbleSort, 
                     gen.generar_ordenado_des,
                     min_n=500, max_n=2000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_bub_opt_exp_1)
# Out:
# Quadratic: time = -0.01 + 1.1E-07*n^2 (sec)  (r=0.005057838991800001, r^2=0.9930809579640831)

# %% [markdown]
# ### Graficación
#
# ### Experimento 1
# #### Comparacion de los 4 algoritmos

# %%
x1 = datos_1_sel_exp_1['measures']
y1 = datos_1_sel_exp_1['times']
x2 = datos_1_ins_exp_1['measures']
y2 = datos_1_ins_exp_1['times']
x3 = datos_1_bub_exp_1['measures']
y3 = datos_1_bub_exp_1['times']
x4 = datos_1_bub_opt_exp_1['measures']
y4 = datos_1_bub_opt_exp_1['times']

aprox_sel_1_exp_1 = [0.00065 + 1.1E-07* x**2 for x in x1]
aprox_ins_1_exp_1 = [-0.0027 + 7.8E-08* x**2 for x in x2]
aprox_bub_1_exp_1 = [-0.0081 + 1.8E-07*x**2 for x in x3]
aprox_bub_opt_1_exp_1 = [-0.01 + 1.1E-07* x**2 for x in x4]
gen.graficar_comparacion(x1, y1, aprox_sel_1_exp_1 , x2, y2, aprox_ins_1_exp_1 , x3, y3, aprox_bub_1_exp_1 , x4, y4, aprox_bub_opt_1_exp_1)

# %% [markdown]
# ## Reproducción experimento 2
# Como se ha mencionado anteriormente, haremos la reproducción del experimento para el caso promedio con una muestra de minima en 500 y maxima en 3500
#
# ### Selection Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_sel_exp_2 = big_o(alg.selectionSort, 
                     gen.generar_aleatorio,
                     min_n=500, max_n=3500,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_sel_exp_2)
# Out:
# Quadratic: time = 0.0022 + 1.1E-07*n^2 (sec)  (r=0.514683864483896, r^2=0.9425620543448242)

# %% [markdown]
# ### Insertion Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_ins_exp_2 = big_o(alg.insertionSort, 
                     gen.generar_aleatorio,
                     min_n= 500, max_n=3500,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_ins_exp_2)
# Out:
# Quadratic: time = 0.0013 + 4.1E-08*n^2 (sec)  (r=0.00413383418448085, r^2=0.9962569670932334)

# %% [markdown]
# ### Bubble Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_exp_2 = big_o(alg.bubbleSort, 
                     gen.generar_aleatorio,
                     min_n=500, max_n=3500,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_bub_exp_2)
# Out:
# Quadratic: time = -0.017 + 1.7E-07*n^2 (sec)  (r=0.06956648127967299, r^2=0.9962192840082156)

# %% [markdown]
# ### Optimized Bubble Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_opt_exp_2 = big_o(alg.optimizedBubbleSort, 
                     gen.generar_ordenado_des,
                     min_n=500, max_n=3500,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_bub_opt_exp_2)
# Out:
# Quadratic: time = -0.0054 + 1E-07*n^2 (sec)  (r=0.007342954646768701, r^2=0.9989116433578119)

# %% [markdown]
# ### Graficación
#
# ### Experimento 2
# #### Comparacion de los 4 algoritmos

# %%
x1 = datos_1_sel_exp_2['measures']
y1 = datos_1_sel_exp_2['times']
x2 = datos_1_ins_exp_2['measures']
y2 = datos_1_ins_exp_2['times']
x3 = datos_1_bub_exp_2['measures']
y3 = datos_1_bub_exp_2['times']
x4 = datos_1_bub_opt_exp_2['measures']
y4 = datos_1_bub_opt_exp_2['times']

aprox_sel_1_exp_2 = [0.0022 + 1.1E-07* x**2 for x in x1]
aprox_ins_1_exp_2 = [0.0013 + 4.1E-08* x**2 for x in x2]
aprox_bub_1_exp_2 = [-0.017 + 1.7E-07* x**2 for x in x3]
aprox_bub_opt_1_exp_2 = [-0.0054 + 1E-07* x**2 for x in x4]
gen.graficar_comparacion(x1, y1, aprox_sel_1_exp_2 , x2, y2, aprox_ins_1_exp_2 , x3, y3, aprox_bub_1_exp_2 , x4, y4, aprox_bub_opt_1_exp_2)

# %% [markdown]
# ## Reproducción experimento 3
# Como se ha mencionado anteriormente, haremos la reproducción del experimento para el mejor caso con una muestra de minima en 500 y maxima en 1000
#
# ### Selection Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_sel_exp_3 = big_o(alg.selectionSort, 
                     gen.generear_ordenado_asc,
                     min_n= 500, max_n=1000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_sel_exp_3)
# Out:
# Quadratic: time = -0.00077 + 1.1E-07*n^2 (sec)  (r=0.00012736236210475938, r^2=0.9957888307041368)

# %% [markdown]
# ### Insertion Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_ins_exp_3 = big_o(alg.insertionSort, 
                     gen.generear_ordenado_asc,
                     min_n= 500, max_n=1000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Linear])

# %%
aprox_asintotica(datos_1_ins_exp_3)
# Out:
# Linear: time = -8.3E-05 + 4.9E-07*n (sec)  (r=1.0752423192656165e-07, r^2=0.7110865109600817)

# %% [markdown]
# ### Bubble Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_exp_3 = big_o(alg.bubbleSort, 
                     gen.generear_ordenado_asc,
                     min_n= 500, max_n=1000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Quadratic])

# %%
aprox_asintotica(datos_1_bub_exp_3)
# Out:
# Quadratic: time = -0.0023 + 1.4E-07*n^2 (sec)  (r=0.00014624728000516777, r^2=0.9967821168339539)

# %% [markdown]
# ### Optimized Bubble Sort
# * Tenemos que para el primer experimento las pruebas empíiricas según su caso respectivo los resultados son los siguientes:

# %%
clase, datos_1_bub_opt_exp_3 = big_o(alg.optimizedBubbleSort, 
                     gen.generear_ordenado_asc,
                     min_n= 500, max_n=1000,
                     n_measures=50, n_repeats=5,
                     verbose=False, return_raw_data=True,
                     classes=[cls.Linear])

# %%
aprox_asintotica(datos_1_bub_opt_exp_3)
# Out:
# Linear: time = -8.2E-06 + 3.1E-07*n (sec)  (r=6.190700882046689e-08, r^2=0.6340142295870796)

# %% [markdown]
# ### Graficación
#
# ### Experimento 3
# #### Comparacion de los 4 algoritmos

# %%
x1 = datos_1_sel_exp_3['measures']
y1 = datos_1_sel_exp_3['times']
x2 = datos_1_ins_exp_3['measures']
y2 = datos_1_ins_exp_3['times']
x3 = datos_1_bub_exp_3['measures']
y3 = datos_1_bub_exp_3['times']
x4 = datos_1_bub_opt_exp_3['measures']
y4 = datos_1_bub_opt_exp_3['times']

aprox_sel_1_exp_3 = [-0.00077 + 1.1E-07*x**2 for x in x1]
aprox_ins_1_exp_3 = [-8.3E-05 + 4.9E-07* x for x in x2]
aprox_bub_1_exp_3 = [-0.0023 + 1.4E-07* x**2 for x in x3]
aprox_bub_opt_1_exp_3 = [-8.2E-06 + 3.1E-07* x for x in x4]
gen.graficar_comparacion(x1, y1, aprox_sel_1_exp_3 , x2, y2, aprox_ins_1_exp_3 , x3, y3, aprox_bub_1_exp_3 , x4, y4, aprox_bub_opt_1_exp_3)

# %%
xs = datos_1_ins_exp_3['measures']
ys = datos_1_ins_exp_3['times']
aprox_ins_1_exp_3 = [-8.3E-05 + 4.9E-07* x for x in xs]
gen.graficar_comportamiento(xs, ys, aprox_ins_1_exp_3)

# %%
xs = datos_1_bub_opt_exp_3['measures']
ys = datos_1_bub_opt_exp_3['times']
aprox_bub_opt_1_exp_3 = [-8.2E-06 + 3.1E-07* x for x in xs]
gen.graficar_comportamiento(xs, ys, aprox_bub_opt_1_exp_3)

# %% [markdown]
# # Conclusiones
#
# Ahora que tenemos los resultados de los experimentos podemos referirnos a la resolución del problema inicial:
#
# * Considerando los algoritmos de ordenamiento por intercambio de adyacentes (selección, inserción, burbuja original, burbuja optimizado), se sabe que presentan complejidad temporal cuadrática en sus casos promedio y peor. A pesar de que su consumo de recurso temporal cae en la misma clase de complejidad, ¿cómo se comparan en cuanto a rendimiento temporal? ¿Hay alguno más eficiente? Si es el caso, ¿cómo se justifica esta diferencia en eficiencia?
#
# Despues de obtener los resultado de los experimentos hemos llegado a la conclusión de que la eficiencia de cada algoritmo puede variar según el caso respectivo en donde lo estemos evaluando.
#
# Según los resultados en nuestros experimentos, podemos concluir lo siguiente:
#
# * El insertionSort es el más eficiente en el caso peor y promedio ya que fue el que mostró tener un mejor rendimiento temporal.
#
# * En el mejor caso el algoritmo burbuja optimizado fue el que tuvo un mejor rendimiento temporal.
#
# * El bubbleSort regular es uno de los algoritmos que tiene peor complejidad temporal debido a su alto numero de comparaciones y escrituras a memoria.
#
# * El selectionSort y el bubbleSort optimizado mostraron tener una complejidad temporal muy similar.
#
# * La razón por la cual es insertionSort es más eficiente que los otros algoritmos de ordenamiento por comparación de adyacencia es porque su número de comparaciones y escrituras en memoria es menor.
#
# * Debido que el insertionSort es el algoritmo con mejor rendimiento temporal en los casos peor y los casos promedio, podemos llegar a la conclusión de que este algoritmo es el mas eficiente en cuanto a todos los algoritmos de ordenamiento por intercambio de adyacentes.
